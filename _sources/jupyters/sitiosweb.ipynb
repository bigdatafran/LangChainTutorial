# %% [markdown]
# # Sitios web
#
# * <a href="https://apxml.com/courses/langchain-production-llm/chapter-1-advanced-langchain-architecture/async-concurrency" target="_blank">Curso sobre LangChain </a>
#
# * <a href="https://langchain-esquemas.vercel.app/" target="_blank">Esquemas dinámicos de LangChain y LangGraph</a>
